# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = tf.keras.utils.image_dataset_from_directory(
    "E:/Paddy_detect/archive",
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 10407 files belonging to 10 classes.
# Using 8326 files for training.

# %%
class_names=dataset.class_names
print(class_names)
# Out:
# ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']

# %%
data_dir = "E:/Paddy_detect/archive"

# %%
normalization_layer=keras.layers.Rescaling(2./255)

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir ,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 10407 files belonging to 10 classes.
# Using 8326 files for training.
# Found 10407 files belonging to 10 classes.
# Using 2081 files for validation.

# %%
val_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
model = keras.Sequential([
    normalization_layer,

    keras.layers.Conv2D(32, 3, activation='relu'),
    keras.layers.MaxPooling2D(),

    keras.layers.Conv2D(64, 3, activation='relu'),
    keras.layers.MaxPooling2D(),

    keras.layers.Conv2D(128, 3, activation='relu'),
    keras.layers.MaxPooling2D(),

    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(len(class_names), activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
# Out:
# Epoch 1/10
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 448s 2s/step - accuracy: 0.3180 - loss: 1.9777 - val_accuracy: 0.4483 - val_loss: 1.5879
# Epoch 2/10
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 422s 2s/step - accuracy: 0.5991 - loss: 1.2425 - val_accuracy: 0.6362 - val_loss: 1.1896
# Epoch 3/10
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 359s 1s/step - accuracy: 0.7886 - loss: 0.6663 - val_accuracy: 0.7453 - val_loss: 0.8920
# Epoch 4/10
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 196s 751ms/step - accuracy: 0.9048 - loss: 0.2937 - val_accuracy: 0.7525 - val_loss: 1.0591
# Epoch 5/10
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 202s 775ms/step - accuracy: 0.9663 - loss: 0.1193 - val_accuracy: 0.7842 - val_loss: 1.0378
# Epoch 6/10
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 197s 754ms/step - accuracy: 0.9791 - loss: 0.0716 - val_accuracy: 0.7857 - val_loss: 1.0367
# Epoch 7/10
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 195s 746ms/step - accuracy: 0.9845 - loss: 0.0573 - val_accuracy: 0.7573 - val_loss: 1.6424
# Epoch 8/10
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 195s 747ms/step - accuracy: 0.9914 - loss: 0.0359 - val_accuracy: 0.7900 - val_loss: 1.2984
# Epoch 9/10
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 201s 770ms/step - accuracy: 0.9924 - loss: 0.0301 - val_accuracy: 0.7900 - val_loss: 1.4780
# Epoch 10/10
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 197s 754ms/step - accuracy: 0.9914 - loss: 0.0392 - val_accuracy: 0.7597 - val_loss: 1.4309

# %%
img = tf.keras.utils.load_img(
    "archive/tungro/100461.jpg",
    target_size=(224, 224)
)

# %%
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

# %%
prediction=model.predict(img_array)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step

# %%
score = tf.nn.softmax(prediction[0])

print("Disease:",
      class_names[np.argmax(score)])

print("Confidence:",
      100 * np.max(score), "%")
# Out:
# Disease: tungro
# Confidence: 23.19693 %

# %%
model.save("paddy_disease_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
